# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import euclidean_distances
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### the aim of this project is to find a new MO SALAH. the player should be a comming star not and not very well known or plays in a top level club
# ### Looking at Salah's features. salah is/has
# * Winger
# * Fast
# * Vision
# * High strength
# * High shooting accuracy
# * High acceleration, stamina, and agility
# * Good with penalties

# %%
df = pd.read_csv('player_stats.csv', encoding= "latin-1")
df.head()
# Out:
#                      player   country  height  weight  age            club  \
# 0  Cristian Castro Devenish  Colombia     192      84   22  Atl. Nacional
# 1          Silaldo Taffarel    Brazil     181      80   31    Corinthians
# 2             Thomas DÃ¤hne   Germany     193      84   29  Holstein Kiel
# 3         Michael Sollbauer   Austria     187      86   33  SK Rapid Wien
# 4             Diego Segovia   Uruguay     191      80   23  Independiente
#
#    ball_control  dribbling  marking  slide_tackle  ...  curve  fk_acc  \
# 0            55         43      NaN            68  ...     32      34
# 1            69         70      NaN            56  ...     65      62
# 2            25         12      NaN            13  ...     20      15
# 3            46         48      NaN            66  ...     25      13
# 4            14          8      NaN            14  ...      9      10
#
#    penalties  volleys  gk_positioning  gk_diving  gk_handling  gk_kicking  \
# ...

# %% [markdown]
# ### A few observations from the dataset
# * The dataset has 5682 players with 41 characteristics
# * It covers players who are over 40 years old
# * It doesn't have a position columns which specifies exactly the player's position
# * The dataset covers the Goal Keepers as well
# * The max value of the player's attributes is 100

# %%
df.shape
# Out:
# (5682, 41)

# %%
df.columns
# Out:
# Index(['player', 'country', 'height', 'weight', 'age', 'club', 'ball_control',
#        'dribbling', 'marking', 'slide_tackle', 'stand_tackle', 'aggression',
#        'reactions', 'att_position', 'interceptions', 'vision', 'composure',
#        'crossing', 'short_pass', 'long_pass', 'acceleration', 'stamina',
#        'strength', 'balance', 'sprint_speed', 'agility', 'jumping', 'heading',
#        'shot_power', 'finishing', 'long_shots', 'curve', 'fk_acc', 'penalties',
#        'volleys', 'gk_positioning', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_reflexes', 'value'],
#       dtype='str')

# %%
df.describe()
# Out:
#             height       weight          age  ball_control    dribbling  \
# count  5682.000000  5682.000000  5682.000000   5682.000000  5682.000000
# mean    181.670539    75.282295    26.316262     58.912179    56.128476
# std       6.829238     6.998971     4.729967     16.567068    18.772075
# min     156.000000    54.000000    17.000000      8.000000     5.000000
# 25%     177.000000    70.000000    23.000000     55.000000    51.000000
# 50%     182.000000    75.000000    26.000000     63.000000    62.000000
# 75%     186.000000    80.000000    30.000000     69.000000    68.000000
# max     204.000000   102.000000    41.000000     94.000000    95.000000
#
#        marking  slide_tackle  stand_tackle   aggression    reactions  ...  \
# count      0.0   5682.000000   5682.000000  5682.000000  5682.000000  ...
# mean       NaN     46.728441     48.820838    56.324006    61.959345  ...
# std        NaN     20.519430     20.975966    16.846410     8.893309  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5682 entries, 0 to 5681
# Data columns (total 41 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player          5682 non-null   str
#  1   country         5682 non-null   str
#  2   height          5682 non-null   int64
#  3   weight          5682 non-null   int64
#  4   age             5682 non-null   int64
#  5   club            5682 non-null   str
#  6   ball_control    5682 non-null   int64
#  7   dribbling       5682 non-null   int64
#  8   marking         0 non-null      float64
#  9   slide_tackle    5682 non-null   int64
#  10  stand_tackle    5682 non-null   int64
#  11  aggression      5682 non-null   int64
#  12  reactions       5682 non-null   int64
#  13  att_position    5682 non-null   int64
#  14  interceptions   5682 non-null   int64
#  15  vision          5682 non-null   int64
#  16  composure       5682 non-null   int64
#  17  crossing        5682 non-null   int64
# ...

# %% [markdown]
# ### By applying Exploratory Data Analysis, we found that
# * The value column is of object data type
# * The marking column is all empty
# * fk_acc column is referring to Free Kick Accuracy
# * No misspellings or mistakes in column names
# * Looking at the duplicated values, there are 3
# #### Thus, changes can be made
# * Remove the null column
# * Change the value column into int64
# * Dropped the repeated players due to a name conversion from different languages

# %%
df.dtypes
# Out:
# player                str
# country               str
# height              int64
# weight              int64
# age                 int64
# club                  str
# ball_control        int64
# dribbling           int64
# marking           float64
# slide_tackle        int64
# stand_tackle        int64
# aggression          int64
# reactions           int64
# att_position        int64
# interceptions       int64
# vision              int64
# composure           int64
# crossing            int64
# short_pass          int64
# long_pass           int64
# acceleration        int64
# stamina             int64
# strength            int64
# balance             int64
# sprint_speed        int64
# agility             int64
# jumping             int64
# heading             int64
# shot_power          int64
# finishing           int64
# long_shots          int64
# curve               int64
# fk_acc              int64
# penalties           int64
# volleys             int64
# ...

# %%
df.isnull().sum()
# Out:
# player               0
# country              0
# height               0
# weight               0
# age                  0
# club                 0
# ball_control         0
# dribbling            0
# marking           5682
# slide_tackle         0
# stand_tackle         0
# aggression           0
# reactions            0
# att_position         0
# interceptions        0
# vision               0
# composure            0
# crossing             0
# short_pass           0
# long_pass            0
# acceleration         0
# stamina              0
# strength             0
# balance              0
# sprint_speed         0
# agility              0
# jumping              0
# heading              0
# shot_power           0
# finishing            0
# long_shots           0
# curve                0
# fk_acc               0
# penalties            0
# volleys              0
# gk_positioning       0
# gk_diving            0
# gk_handling          0
# gk_kicking           0
# gk_reflexes          0
# ...

# %%
cols = df.columns.drop(['player','club','marking'])

df[df.duplicated(subset=cols, keep=False)]
# Out:
#                player  country  height  weight  age                 club  \
# 154   Maxime CrÃ©peau   Canada     180      88   29                LAFC
# 156    Stefan Thesker  Germany     190      84   32       Holstein Kiel
# 157      Cameron John  England     181      78   24            Rochdale
# 158   Maxime CrÃ©peau   Canada     180      88   29                LAFC
# 159    Stefan Thesker  Germany     190      84   32       Holstein Kiel
# 160      Cameron John  England     181      78   24            Rochdale
# 916       Sadio ManÃ©  Senegal     174      69   31  FC Bayern MÃ¼nchen
# 5229   Kylian MbappÃ©   France     182      73   24            Paris SG
# 5675    Kylian Mbappé   France     182      73   24             Paris SG
# 5678       Sadio Mané  Senegal     174      69   31    FC Bayern München
#
#       ball_control  dribbling  marking  slide_tackle  ...  curve  fk_acc  \
# 154             45         19      NaN            17  ...     16      14
# ...

# %%
df.drop(['marking'], axis = 1, inplace = True)

# %%
df['value'] = df['value'].str.split('$', expand= True)[1]
df['value'] = df['value'].str.replace('.', '').astype("int64")

# %%
df.drop_duplicates(subset= cols, keep='first', inplace= True)

# %% [markdown]
# ### Filtering the dataset based on the criteria we have specified
#  1. neglecting the Goal Keepers
#  2. the Players under 18
#  3. the Players over 27

# %%
dropped_columns = ['gk_positioning', 'gk_diving', 'gk_handling', 'gk_kicking','gk_reflexes']

df.drop(dropped_columns, axis= 1, inplace= True)

# %%
salah_df = df[df['player'] == 'Mohamed Salah']

# %%
# adding salah to the dataset to use it later
df_filtered = df[df['age'].between(19, 27)]

df_filtered = pd.concat([df_filtered, salah_df])

# %% [markdown]
# Looking for a player like mo salah, the player should have a high
#
# 1) acceleration
# 2) sprint_speed
# 3) agility
# 4) balance
# 5) dribbling
# 6) ball_control
# 7) finishing
# 8) att_postion
# 9) reactions
# 10) composure
#
# To do that, we need to find the position that the player plays in. I am aiming for attack, mid, defence

# %%
categorical_columns = ['player','country', 'club']
encoder = OrdinalEncoder()

encoded = encoder.fit_transform(df_filtered[categorical_columns])

e = pd.DataFrame(encoded, columns= encoder.get_feature_names_out())

# %%
encoded, e
# Out:
# (array([[ 581.,   24.,   58.],
#         [ 733.,  115.,  319.],
#         [ 597.,  107.,   69.],
#         ...,
#         [2752.,  103.,  384.],
#         [2258.,  111.,   24.],
#         [2324.,   35.,  372.]], shape=(3388, 3)),
#        player  country   club
#  0      581.0     24.0   58.0
#  1      733.0    115.0  319.0
#  2      597.0    107.0   69.0
#  3     2604.0     91.0   85.0
#  4     2944.0     75.0  333.0
#  ...      ...      ...    ...
#  3383  1549.0     92.0  103.0
#  3384   635.0    116.0  118.0
#  3385  2752.0    103.0  384.0
#  3386  2258.0    111.0   24.0
#  3387  2324.0     35.0  372.0
#
#  [3388 rows x 3 columns])

# %%
df_filtered.columns
# Out:
# Index(['player', 'country', 'height', 'weight', 'age', 'club', 'ball_control',
#        'dribbling', 'slide_tackle', 'stand_tackle', 'aggression', 'reactions',
#        'att_position', 'interceptions', 'vision', 'composure', 'crossing',
#        'short_pass', 'long_pass', 'acceleration', 'stamina', 'strength',
#        'balance', 'sprint_speed', 'agility', 'jumping', 'heading',
#        'shot_power', 'finishing', 'long_shots', 'curve', 'fk_acc', 'penalties',
#        'volleys', 'value'],
#       dtype='str')

# %%
# Creating a positional score for every player
df_filtered = df_filtered.copy()

df_filtered['attacking_score'] = (
    df_filtered['finishing'] * 0.25 +
    df_filtered['shot_power'] * 0.15 +
    df_filtered['att_position'] * 0.15 +
    df_filtered['sprint_speed'] * 0.10 +
    df_filtered['acceleration'] * 0.10 +
    df_filtered['dribbling'] * 0.10 +
    df_filtered['ball_control'] * 0.05 +
    df_filtered['volleys'] * 0.05 +
    df_filtered['long_shots'] * 0.05
)

df_filtered['midfield_score'] = (
    df_filtered['short_pass'] * 0.20 +
    df_filtered['long_pass'] * 0.15 +
    df_filtered['vision'] * 0.15 +
    df_filtered['ball_control'] * 0.15 +
    df_filtered['composure'] * 0.10 +
    df_filtered['stamina'] * 0.10 +
    df_filtered['agility'] * 0.05 +
    df_filtered['balance'] * 0.05 +
    df_filtered['crossing'] * 0.05
)

df_filtered['defensive_score'] = (
    df_filtered['stand_tackle'] * 0.25 +
    df_filtered['slide_tackle'] * 0.20 +
    df_filtered['interceptions'] * 0.20 +
    df_filtered['strength'] * 0.10 +
    df_filtered['aggression'] * 0.10 +
    df_filtered['heading'] * 0.05 +
    df_filtered['jumping'] * 0.05 +
    df_filtered['reactions'] * 0.05
)

# %%
def get_position(row):
    if row['attacking_score'] > row['midfield_score'] and row['defensive_score']:
        return 'att'
    elif row['midfield_score'] > row['attacking_score'] and row['midfield_score'] > row['defensive_score']:
        return 'mid'
    else:
        return 'def'

# %%
df_filtered['position_name']= df_filtered.apply(get_position, axis=1)

# %%
# while checking the output of this if condition rule. it turns out it is simple yet effective
df_filtered[['player','position_name']][:10]
# Out:
#                       player position_name
# 0   Cristian Castro Devenish           def
# 4              Diego Segovia           mid
# 6            CÃ©dric Zesiger           def
# 7                Pedro Gomes           def
# 9               Sibiry Keita           att
# 10        Abdullah Al Hamdan           att
# 12          Vilmer RÃ¶nnberg           def
# 14          Tyreece Campbell           att
# 15              John Souttar           def
# 17            Kim Geon Woong           def

# %% [markdown]
# Since attacking is not the only thing a typical player would do we need to add a rule that gives a higher weight for attacking but not totally neglect the other positions so:
#
# let's suppose that we will give 60% for attacking, 25% for middle, 15% for defence and we can test this afterwards
#
# since we have so attributes that have different scales (Ex. weight and height)we may need to use a scaler for the data

# %%
df_filtered['star_player'] = (df_filtered['attacking_score'] * .6 + 
                              df_filtered['midfield_score'] * .25 +
                              df_filtered['defensive_score'] * .15 )

# %%
# the percentage of this player being a star
df_filtered['star_percentile'] = df_filtered['star_player'].rank(pct = True) * 100

# %%
# lets have a look on the top 20 players we got from out rule 
# the output shows some of the greatest players who play for world's best clubs
df_filtered.sort_values('star_player', ascending = False).iloc[:20]
# Out:
#                       player      country  height  weight  age  \
# 5229          Kylian MbappÃ©       France     182      73   24
# 5677           Mohamed Salah        Egypt     175      71   31
# 3863       Federico Valverde      Uruguay     182      78   25
# 1965          Erling Haaland       Norway     195      94   23
# 3416       Lautaro MartÃ­nez    Argentina     174      72   26
# 961              Bukayo Saka      England     178      65   21
# 862      NicolÃ¡s De la Cruz      Uruguay     167      65   26
# 3770         Federico Chiesa        Italy     175      70   25
# 2129              Phil Foden      England     171      69   23
# 2327  Franck Yannick KessiÃ©  Ivory Coast     183      88   26
# 1319          Renato Sanches     Portugal     176      70   26
# 5447         Marcus Rashford      England     186      70   25
# 3649            JoÃ£o FÃ©lix     Portugal     181      72   23
# 1032        JuliÃ¡n Ãlvarez    Argentina     170      71   23
# ...

# %% [markdown]
# applying some filters again
# - the player is in an attacking position
# - his chance to be a star is higher than 95%
# - removing  players who play for top tier clubs as it may be hard to sign contracts with them

# %%
salah = df_filtered[df_filtered['player'] == 'Mohamed Salah']

# %%
top_tier_clubs = ['Paris SG ', 'Manchester City ', 'Inter ', 'Arsenal ', 'Juventus ',
       'Manchester Utd ', 'FC Bayern MÃ¼nchen ', 'Liverpool ','FC Barcelona ','Real Madrid ','Chelsea ']

# %%
# note we left salah in the top players variable to be scaled
top_players = df_filtered.copy()
top_players = top_players[top_players['position_name'] == 'att']
top_players = top_players[-top_players['club'].isin(top_tier_clubs)]
top_players = top_players[top_players['star_percentile'] >= 95]
top_players.reset_index(inplace= True, drop = True)

# %%
top_players.sort_values('star_percentile', ascending = False)
# Out:
#                    player      country  height  weight  age  \
# 63          Mohamed Salah        Egypt     175      71   31
# 37          Maxwel Cornet  Ivory Coast     179      69   26
# 62              Oyarzabal        Spain     181      79   26
# 13           Jacob Ramsey      England     180      72   22
# 55         Martin Terrier       France     184      78   26
# ..                    ...          ...     ...     ...  ...
# 0   Dominic Calvert-Lewin      England     187      71   26
# 3         Justin Kluivert  Netherlands     172      66   24
# 24              Elye Wahi       France     184      74   20
# 60               TrincÃ£o     Portugal     184      76   23
# 4            Luiz AraÃºjo       Brazil     175      70   27
#
#                  club  ball_control  dribbling  slide_tackle  stand_tackle  \
# 63          Liverpool            86         88            41            43
# 37          West Ham             76         79            66            70
# ...

# %%
# we included age and value columns because we don't need the player to be near salah's age or market value
non_scaled_columns = ['player', 'country', 'club','age','value','position_name']

scaled_columns = [x for x in list(top_players.columns) if x not in non_scaled_columns]

# %%
scaler = StandardScaler()

scaled = scaler.fit_transform(top_players[scaled_columns])

# %%
# salah_scaled = scaler.fit_transform(salah[scaled_columns])

# %%
salah_vector = scaled[top_players['player'] == 'Mohamed Salah']

# %%
salah_vector
# Out:
# array([[-0.80282133, -0.51667916,  2.20984345,  2.03571753,  0.13727948,
#         -0.12369325, -0.20456948,  3.57091376,  3.39843566,  0.9613495 ,
#          2.49020169,  2.97702289,  1.70016676,  3.03028937,  1.93908335,
#          1.06864342,  1.49407669,  0.79847635,  1.71777044,  1.18045639,
#          1.33691703, -0.01647798, -0.45208202,  1.25966944,  3.32671432,
#          2.36240422,  1.78563272,  0.92264976,  2.24062615,  2.07521135,
#          4.0066674 ,  3.95828101,  0.42761374,  4.94408693,  2.29543633]])

# %% [markdown]
# #### using TSNE is better cuz the cost function is not convex which means it will capture more detailed information than PCA
# #### Research showed 2 different ways
# 1) finding the distince between the players and Salah, comparing a number by number using a method like Euclidean distance
# 2) finding the similarity to salah which dives deep into the stats and tries to undersand if the player's style like Salah or not
#
# for this specific problem i am looking for a top-tier player like salah not the play style it self so i will go with Euclidean distance
#
# 1) using euclidean distance we have the distance between the player and salah in statistics. (the smaller the distance the closer the player to Salah)
# 2) using tsne we had a X,Y co-ordinates to visualize the players close to salah. we reduced the data into two informative attributes.
# 3) using K-means we clustered the data and did research on the players that can be clustered with salah in terms of numbers in general
#
# noticeing the output, the KMeans clustering algorithm showed 20 players in salah's cluster. and by looking at the Eucladian distance, we chose 4 players which are close to salah
# - Oyarzabal
# - Martin Terrier
# - Amine Gouiri
# - Rafael LeÃ£o
#
# next step is to do some analysis and visualisations on these players to get to know their attributes better

# %%
scaled.shape, salah_vector.shape
# Out:
# ((64, 35), (1, 35))

# %%
top_players['distance_to_salah'] = euclidean_distances(scaled, salah_vector)

# %%
top_players.sort_values('distance_to_salah').iloc[1:5]
# Out:
#             player   country  height  weight  age               club  \
# 62       Oyarzabal     Spain     181      79   26     Real Sociedad
# 55  Martin Terrier    France     184      78   26  Stade Rennais FC
# 35    Amine Gouiri    France     181      83   23  Stade Rennais FC
# 57    Rafael LeÃ£o  Portugal     188      81   24             Milan
#
#     ball_control  dribbling  slide_tackle  stand_tackle  ...  penalties  \
# 62            85         84            30            32  ...         84
# 55            82         80            34            31  ...         73
# 35            80         82            32            41  ...         78
# 57            86         89            21            24  ...         63
#
#     volleys     value  attacking_score  midfield_score  defensive_score  \
# 62       74  40500000            82.00           80.55            41.30
# 55       79  28500000            82.45           76.65            44.70
# ...

# %%
tsne = TSNE(n_components=2,
           perplexity= 2,
           random_state= 42)
coords = tsne.fit_transform(scaled)

# %%
top_players['x'] = coords[:,0]
top_players['y'] = coords[:,1]

plt.figure(figsize=(12,10))
plt.scatter(top_players['x'], top_players['y'])

for _, row in top_players.iterrows():
    if row['player'] == 'Mohamed Salah' or row['player'] in top_players['player'].values:
        plt.scatter(row['x'], row['y'], s=200)
        plt.annotate(row['player'],
                     (row['x'], row['y']))
        plt.text(row['x'], row['y'], row['player'])
# Out:
# C:\Users\alaa_\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 135 (\x87) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\alaa_\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\IPython\core\events.py:100: UserWarning: Glyph 153 (\x99) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\alaa_\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 135 (\x87) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\alaa_\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 153 (\x99) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
kmeans = KMeans(n_clusters= 3, random_state=42)

top_players['cluster'] = kmeans.fit_predict(scaled)

# %%
top_players[top_players['cluster'] == 1].sort_values('distance_to_salah')
# Out:
#                    player    country  height  weight  age               club  \
# 63          Mohamed Salah      Egypt     175      71   31          Liverpool
# 62              Oyarzabal      Spain     181      79   26     Real Sociedad
# 55         Martin Terrier     France     184      78   26  Stade Rennais FC
# 35           Amine Gouiri     France     181      83   23  Stade Rennais FC
# 57           Rafael LeÃ£o   Portugal     188      81   24             Milan
# 14           Jarrod Bowen    England     175      70   26          West Ham
# 2         Nikola VlaÅ¡iÄ    Croatia     178      79   25            Torino
# 25      Giacomo Raspadori      Italy     172      69   23         Napoli FC
# 26   Valentin Castellanos  Argentina     178      74   24         Girona FC
# 58      Luimo Boas Santos     Brazil     176      73   23            Brazil
# 5           Tammy Abraham    England     195      86   25              Roma
# ...

# %%
distance_max = top_players['distance_to_salah'].max()
top_players['distance_percentage'] = (1 - top_players['distance_to_salah'] / distance_max ) * 100

# %%
players = top_players.sort_values(by = 'distance_percentage',ascending= False).head(5)
players
# Out:
#             player   country  height  weight  age               club  \
# 63   Mohamed Salah     Egypt     175      71   31          Liverpool
# 62       Oyarzabal     Spain     181      79   26     Real Sociedad
# 55  Martin Terrier    France     184      78   26  Stade Rennais FC
# 35    Amine Gouiri    France     181      83   23  Stade Rennais FC
# 57    Rafael LeÃ£o  Portugal     188      81   24             Milan
#
#     ball_control  dribbling  slide_tackle  stand_tackle  ...  midfield_score  \
# 63            86         88            41            43  ...           84.55
# 62            85         84            30            32  ...           80.55
# 55            82         80            34            31  ...           76.65
# 35            80         82            32            41  ...           75.75
# 57            86         89            21            24  ...           76.30
#
#     defensive_score  position_name  star_player  star_percentile  \
# ...

# %% [markdown]
# Now we have 3 players who are close to Salah
# 1) Oyarzabal
# 2) Martin Terrier
# 3) Amine Gouiri
#
# to visualize them we need to select specific mertics

# %%
metrics = [
    'ball_control','dribbling','acceleration',
    'sprint_speed','agility','finishing',
    'shot_power','vision','composure'
]

angles = np.linspace(0, 2*np.pi, len(metrics), endpoint=False)
angles = np.concatenate((angles, [angles[0]]))

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, polar=True)

for _, row in players.iterrows():
    values = row[metrics].tolist()
    values += values[:1]
    
    ax.plot(angles, values, label=row['player'])
    ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
plt.legend()

# %%
heatmap_df = players.set_index('player')[metrics]

sns.heatmap(
    heatmap_df,
    annot=True,
    cmap='YlGnBu'
)

plt.title('Player Attribute Comparison')
plt.show()

# %%
metrics = [
    'finishing',
    'dribbling',
    'sprint_speed',
    'vision'
]

plot_df = players.melt(
    id_vars='player',
    value_vars=metrics,
    var_name='Metric',
    value_name='Rating'
)

import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(
    data=plot_df,
    x='Metric',
    y='Rating',
    hue='player',
)

plt.title('Salah vs Other Players')
plt.show()

# %%
players
# Out:
#             player   country  height  weight  age               club  \
# 63   Mohamed Salah     Egypt     175      71   31          Liverpool
# 62       Oyarzabal     Spain     181      79   26     Real Sociedad
# 55  Martin Terrier    France     184      78   26  Stade Rennais FC
# 35    Amine Gouiri    France     181      83   23  Stade Rennais FC
# 57    Rafael LeÃ£o  Portugal     188      81   24             Milan
#
#     ball_control  dribbling  slide_tackle  stand_tackle  ...  midfield_score  \
# 63            86         88            41            43  ...           84.55
# 62            85         84            30            32  ...           80.55
# 55            82         80            34            31  ...           76.65
# 35            80         82            32            41  ...           75.75
# 57            86         89            21            24  ...           76.30
#
#     defensive_score  position_name  star_player  star_percentile  \
# ...

# %%
plt.figure(figsize=(12,10))
plt.scatter(players['x'], players['y'])

for _, row in players.iterrows():
    if row['player'] == 'Mohamed Salah' or row['player'] in players['player'].values:
        plt.scatter(row['x'], row['y'], s=200)
        plt.annotate(row['player'],
                     (row['x'], row['y']))
        plt.text(row['x'], row['y'], row['player'])

# %% [markdown]
# # Looking at the visualisations, in my opinion, Rafael LeÃ£o has the opportunity to be the new Salah as his statistics are incredibly good and he is young, so there is still room for improvement

# %%
final_players_list = players['player'].to_list()
players_ds = df[df['player'].isin(final_players_list)]

# %%
def position_scoring(players_ds):
    players_ds['attacking_score'] = (
        players_ds['finishing'] * 0.25 +
        players_ds['shot_power'] * 0.15 +
        players_ds['att_position'] * 0.15 +
        players_ds['sprint_speed'] * 0.10 +
        players_ds['acceleration'] * 0.10 +
        players_ds['dribbling'] * 0.10 +
        players_ds['ball_control'] * 0.05 +
        players_ds['volleys'] * 0.05 +
        players_ds['long_shots'] * 0.05
    )
    
    players_ds['midfield_score'] = (
        players_ds['short_pass'] * 0.20 +
        players_ds['long_pass'] * 0.15 +
        players_ds['vision'] * 0.15 +
        players_ds['ball_control'] * 0.15 +
        players_ds['composure'] * 0.10 +
        players_ds['stamina'] * 0.10 +
        players_ds['agility'] * 0.05 +
        players_ds['balance'] * 0.05 +
        players_ds['crossing'] * 0.05
    )
    
    players_ds['defensive_score'] = (
        players_ds['stand_tackle'] * 0.25 +
        players_ds['slide_tackle'] * 0.20 +
        players_ds['interceptions'] * 0.20 +
        players_ds['strength'] * 0.10 +
        players_ds['aggression'] * 0.10 +
        players_ds['heading'] * 0.05 +
        players_ds['jumping'] * 0.05 +
        players_ds['reactions'] * 0.05
    )

# %%
def get_position(row):
    if row['attacking_score'] > row['midfield_score'] and row['defensive_score']:
        return 'att'
    elif row['midfield_score'] > row['attacking_score'] and row['midfield_score'] > row['defensive_score']:
        return 'mid'
    else:
        return 'def'
        
def apply_position(players_ds):
    players_ds['position_name']= players_ds.apply(get_position, axis=1)
    return players_ds

# %%
def star_player(players_ds):
    players_ds['star_player'] = (players_ds['attacking_score'] * .6 + 
                                  players_ds['midfield_score'] * .25 +
                                  players_ds['defensive_score'] * .15 )
    # the percentage of this player being a star
    players_ds['star_percentile'] = players_ds['star_player'].rank(pct = True) * 100
    return players_ds

# %%
def distance_to_salah(players_ds):
    # Euclidean distance
    scaled = scaler.transform(players_ds[scaled_columns])
    salah_vector = scaled[players_ds['player'] == 'Mohamed Salah']
    players_ds['distance_to_salah'] = euclidean_distances(scaled, salah_vector)
    
    # TSNE 
    coords = tsne.fit_transform(scaled)
    players_ds['x'] = coords[:,0]
    players_ds['y'] = coords[:,1]
    
    # K-Means Cluster
    players_ds['cluster'] = kmeans.fit_predict(scaled)
    
    distance_max = players_ds['distance_to_salah'].max()
    players_ds['distance_percentage'] = (1 - players_ds['distance_to_salah'] / distance_max ) * 100
    return players_ds

# %% [markdown]
# # Add your player here and give it a go

# %%
your_player = {'player': '',
 'country': '',
 'height': ,
 'weight': ,
 'age': ,
 'club': '',
 'ball_control': ,
 'dribbling': ,
 'slide_tackle': ,
 'stand_tackle': ,
 'aggression': ,
 'reactions': ,
 'att_position': ,
 'interceptions': ,
 'vision': ,
 'composure': ,
 'crossing': ,
 'short_pass':,
 'long_pass': ,
 'acceleration': ,
 'stamina': ,
 'strength': ,
 'balance': ,
 'sprint_speed': ,
 'agility': ,
 'jumping': ,
 'heading': ,
 'shot_power': ,
 'finishing': ,
 'long_shots': ,
 'curve': ,
 'fk_acc': ,
 'penalties': ,
 'volleys': ,
 'value': }

# %%
players_ds = pd.concat([players_ds,your_player.to_frame().T], ignore_index= True)

# %%
position_scoring(players_ds)
apply_position(players_ds)
star_player(players_ds)
distance_to_salah(players_ds)
# Out:
#                      player   country height weight age               club  \
# 0              Amine Gouiri    France    181     83  23  Stade Rennais FC
# 1            Martin Terrier    France    184     78  26  Stade Rennais FC
# 2              Rafael LeÃ£o  Portugal    188     81  24             Milan
# 3                 Oyarzabal     Spain    181     79  26     Real Sociedad
# 4             Mohamed Salah     Egypt    175     71  31          Liverpool
# 5  Cristian Castro Devenish  Colombia    192     84  22     Atl. Nacional
#
#   ball_control dribbling slide_tackle stand_tackle  ... midfield_score  \
# 0           80        82           32           41  ...          75.75
# 1           82        80           34           31  ...          76.65
# 2           86        89           21           24  ...           76.3
# 3           85        84           30           32  ...          80.55
# 4           86        88           41           43  ...          84.55
# ...
